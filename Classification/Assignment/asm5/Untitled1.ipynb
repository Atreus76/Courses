# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('dataset/weatherAUS.csv')

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
X = data.drop(['Date', 'RainTomorrow'], axis=1)
y = data['RainTomorrow']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  object
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
# ...

# %%
categorical = [var for var in X.columns if X[var].dtype == 'O']

# %%
numerical = [var for var in X.columns if X[var].dtype != 'O']

# %%
X[categorical].head()
# Out:
#   Location WindGustDir WindDir9am WindDir3pm RainToday
# 0   Albury           W          W        WNW        No
# 1   Albury         WNW        NNW        WSW        No
# 2   Albury         WSW          W        WSW        No
# 3   Albury          NE         SE          E        No
# 4   Albury           W        ENE         NW        No

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
for df in [X_train, X_test]:
    for col in numerical:
        col_median = df[col].median()
        df[col].fillna(col_median, inplace=True)

# %%
X_train[numerical].isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RISK_MM          0
# dtype: int64

# %%
X_train_categorical = X_train[categorical]

# %%
X_train_categorical = pd.get_dummies(X_train_categorical)

# %%
X_train_categorical.head()
# Out:
#         Location_Adelaide  Location_Albany  Location_Albury  \
# 110803                  0                0                0
# 87289                   0                0                0
# 134949                  0                0                0
# 85553                   0                0                0
# 16110                   0                0                0
#
#         Location_AliceSprings  Location_BadgerysCreek  Location_Ballarat  \
# 110803                      0                       0                  0
# 87289                       0                       0                  0
# 134949                      1                       0                  0
# 85553                       0                       0                  0
# 16110                       0                       0                  0
#
#         Location_Bendigo  Location_Brisbane  Location_Cairns  \
# 110803                 0                  0                0
# ...

# %%
X_test_categorical = X_test[categorical]
X_test_categorical = pd.get_dummies(X_test_categorical)

# %%
X_train_numerical = X_train[numerical]
X_test_numerical = X_test[numerical]

# %%
train = pd.concat(X_train_categorical, X_train_numerical)
test = pd.concat(X_test_categorical, X_test_numerical)
# Out:
# C:\Users\Bang\AppData\Local\Temp\ipykernel_15876\1274692428.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   train = pd.concat(X_train_categorical, X_train_numerical)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15876\1274692428.py in <module>
# ----> 1 train = pd.concat(X_train_categorical, X_train_numerical)
#       2 test = pd.concat(X_test_categorical, X_test_numerical)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
